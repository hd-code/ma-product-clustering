# %%
from IPython.display import display
import pandas as pd

from src import akeneo

# %%
cache = akeneo.load_cache_from_env()

# %%
lists = [
    ("attribute-groups", cache.attribute_groups),
    ("attributes", cache.attributes),
    ("categories", cache.categories),
    ("channels", cache.channels),
    ("currencies", cache.currencies),
    ("families", cache.families),
    ("locales", cache.locales),
    ("measurements", cache.measurements),
    ("products", cache.products),
]

for name, data in lists:
    df = pd.DataFrame(data)
    print(f"--- {name} -------------------------------")
    display(df)
# Out:
# --- attribute-groups -------------------------------
#              code         labels  sort_order  \
# 0           color          Color           8
# 1          design         Design           3
# 2       ecommerce      Ecommerce           6
# 3             erp            ERP           1
# 4   manufacturing  Manufacturing           6
# 5       marketing      Marketing           0
# 6          medias          Media           9
# 7           other          Other          10
# 8         product        Product           4
# 9            size           Size           8
# 10      technical      Technical           2
#
#                                            attributes
# 0                       [main_color, secondary_color]
# 1                                      [tshirt_style]
# 2            [meta_title, meta_description, keywords]
# 3               [sku, price, erp_name, ean, supplier]
# 4              [container_material, tshirt_materials]
# 5   [name, description, response_time, release_dat...
# 6   [picture, pdf_description, image, notice, vari...
# 7                                                  []
# 8   [composition, wash_temperature, care_instructi...
# 9                                     [clothing_size]
# 10  [weight, maximum_scan_size, color_scanning, po...
# --- attributes -------------------------------
#                       code                         type  \
# 0            auto_exposure           AttributeType.BOOL
# 1   auto_focus_assist_beam           AttributeType.BOOL
# 2          auto_focus_lock           AttributeType.BOOL
# 3         auto_focus_modes           AttributeType.TEXT
# 4        auto_focus_points         AttributeType.NUMBER
# ..                     ...                          ...
# 72         variation_image          AttributeType.IMAGE
# 73          variation_name           AttributeType.TEXT
# 74            viewing_area         AttributeType.METRIC
# 75        wash_temperature  AttributeType.SELECT_SINGLE
# 76                  weight         AttributeType.METRIC
#
#                     labels  localizable  scopable  unique      group  \
# 0            Auto exposure        False     False   False  technical
# 1          Auto focus beam        False     False   False  technical
# 2          Auto focus lock        False     False   False  technical
# 3         Auto focus modes         True     False   False  technical
# 4        Auto focus points        False     False   False  technical
# ..                     ...          ...       ...     ...        ...
# 72         Variant picture        False     False   False     medias
# 73            Variant Name         True     False   False  marketing
# 74  Effective viewing area        False     False   False  technical
# 75        Wash temperature        False     False   False    product
# 76                  Weight        False     False   False  technical
#
#    group_labels  sort_order allowed_extensions  ... max_file_size  \
# 0     Technical          39                 []  ...          None
# 1     Technical          34                 []  ...          None
# 2     Technical          33                 []  ...          None
# 3     Technical          31                 []  ...          None
# 4     Technical          32                 []  ...          None
# ..          ...         ...                ...  ...           ...
# 72        Media          20   [png, jpeg, jpg]  ...          None
# 73    Marketing           4                 []  ...          None
# 74    Technical          20                 []  ...          None
# 75      Product           6                 []  ...          None
# 76    Technical           1                 []  ...          None
#
#    metric_family minimum_input_length negative_allowed number_min number_max  \
# 0           None                 None             None       None       None
# 1           None                 None             None       None       None
# 2           None                 None             None       None       None
# 3           None                 None             None       None       None
# 4           None                 None            False       None       None
# ..           ...                  ...              ...        ...        ...
# 72          None                 None             None       None       None
# 73          None                 None             None       None       None
# 74        Length                 None            False       None       None
# 75          None                 None             None       None       None
# 76        Weight                 None            False       None       None
#
#    reference_data_name validation_rule validation_regexp wysiwyg_enabled
# 0                 None            None              None            None
# 1                 None            None              None            None
# 2                 None            None              None            None
# 3                 None            None              None            None
# 4                 None            None              None            None
# ..                 ...             ...               ...             ...
# 72                None            None              None            None
# 73                None            None              None            None
# 74                None            None              None            None
# 75                None            None              None            None
# 76                None            None              None            None
#
# [77 rows x 28 columns]
# --- categories -------------------------------
#                      code              labels          parent
# 0                  master      Master catalog            None
# 1          tvs_projectors  TVs and projectors          master
# 2             pc_monitors         PC Monitors  tvs_projectors
# 3                 led_tvs             LED TVs  tvs_projectors
# 4                 cameras             Cameras          master
# ..                    ...                 ...             ...
# 163             suppliers           Suppliers            None
# 164        supplier_mongo               Mongo       suppliers
# 165         supplier_zaro                Zaro       suppliers
# 166  supplier_the_tootles         The Tootles       suppliers
# 167       supplier_abibas              Abibas       suppliers
#
# [168 rows x 3 columns]
# --- channels -------------------------------
#         code     labels category_tree conversion_units  currencies  \
# 0  ecommerce  Ecommerce        master               {}  [USD, EUR]
# 1     mobile     Mobile        master               {}  [USD, EUR]
# 2      print      Print        master               {}  [USD, EUR]
#
#                  locales
# 0  [de_DE, en_US, fr_FR]
# 1  [de_DE, en_US, fr_FR]
# 2  [de_DE, en_US, fr_FR]
# --- currencies -------------------------------
#     code  enabled
# 0    ADP    False
# 1    AED    False
# 2    AFA    False
# 3    AFN    False
# 4    ALK    False
# ..   ...      ...
# 289  ZRN    False
# 290  ZRZ    False
# 291  ZWD    False
# 292  ZWL    False
# 293  ZWR    False
#
# [294 rows x 2 columns]
# --- families -------------------------------
#                   code                  labels  \
# 0          accessories             Accessories
# 1           camcorders              Camcorders
# 2             clothing                Clothing
# 3      digital_cameras         Digital cameras
# 4           headphones              Headphones
# 5   laser_led_printers  Laser and LED printers
# 6              led_tvs                 LED TVs
# 7         loudspeakers            Loudspeakers
# 8          mp3_players             MP3 players
# 9                 mugs                    Mugs
# 10    multifunctionals        Multifunctionals
# 11         pc_monitors             PC Monitors
# 12            scanners                Scanners
# 13               shoes                   Shoes
# 14             tablets                 Tablets
# 15             tshirts                T-shirts
# 16             webcams                 Webcams
#
#                                            attributes
# 0   [brand, collection, color, composition, descri...
# 1   [description, image_stabilizer, name, optical_...
# 2   [brand, care_instructions, collection, color, ...
# 3   [auto_exposure, auto_focus_assist_beam, auto_f...
# 4   [description, headphone_connectivity, name, pi...
# 5   [description, maximum_print_size, name, pictur...
# 6   [description, display_diagonal, name, picture,...
# 7   [description, name, picture, power_requirement...
# 8   [description, name, picture, power_requirement...
# 9   [container_material, description, main_color, ...
# 10  [color_scanning, description, maximum_print_si...
# 11  [description, display_color, display_diagonal,...
# 12  [color_scanning, description, maximum_scan_siz...
# 13  [brand, collection, color, composition, descri...
# 14  [description, name, picture, power_requirement...
# 15  [clothing_size, description, main_color, name,...
# 16  [description, maximum_frame_rate, maximum_vide...
# --- locales -------------------------------
#       code  enabled
# 0    af_ZA    False
# 1    am_ET    False
# 2    ar_AE    False
# 3    ar_BH    False
# 4    ar_DZ    False
# ..     ...      ...
# 205  zh_HK    False
# 206  zh_MO    False
# 207  zh_SG    False
# 208  zh_TW    False
# 209  zu_ZA    False
#
# [210 rows x 2 columns]
# --- measurements -------------------------------
#               code           labels      standard_unit_code  \
# 0            Angle            Angle                  RADIAN
# 1             Area             Area            SQUARE_METER
# 2           Binary           Binary                    BYTE
# 3       Brightness       Brightness                   LUMEN
# 4      Capacitance      Capacitance                   FARAD
# 5          CaseBox        Packaging                   PIECE
# 6          Decibel          Decibel                 DECIBEL
# 7         Duration         Duration                  SECOND
# 8   ElectricCharge  Electric charge              AMPEREHOUR
# 9           Energy           Energy                   JOULE
# 10           Force            Force                  NEWTON
# 11       Frequency        Frequency                   HERTZ
# 12       Intensity        Intensity                  AMPERE
# 13          Length           Length                   METER
# 14           Power            Power                    WATT
# 15        Pressure         Pressure                     BAR
# 16      Resistance       Resistence                     OHM
# 17           Speed            Speed        METER_PER_SECOND
# 18     Temperature      Temperature                  KELVIN
# 19         Voltage          Voltage                    VOLT
# 20          Volume           Volume             CUBIC_METER
# 21      VolumeFlow      Volume flow  CUBIC_METER_PER_SECOND
# 22          Weight           Weight                KILOGRAM
#
#                                                 units
# 0   {'RADIAN': {'code': 'RADIAN', 'labels': 'Radia...
# 1   {'SQUARE_MILLIMETER': {'code': 'SQUARE_MILLIME...
# 2   {'CHAR': {'code': 'CHAR', 'labels': 'Char', 'c...
# 3   {'LUMEN': {'code': 'LUMEN', 'labels': 'Lumen',...
# 4   {'ATTOFARAD': {'code': 'ATTOFARAD', 'labels': ...
# 5   {'PIECE': {'code': 'PIECE', 'labels': 'Piece',...
# 6   {'DECIBEL': {'code': 'DECIBEL', 'labels': 'Dec...
# 7   {'MILLISECOND': {'code': 'MILLISECOND', 'label...
# 8   {'MILLIAMPEREHOUR': {'code': 'MILLIAMPEREHOUR'...
# 9   {'JOULE': {'code': 'JOULE', 'labels': 'joule',...
# 10  {'MILLINEWTON': {'code': 'MILLINEWTON', 'label...
# 11  {'HERTZ': {'code': 'HERTZ', 'labels': 'Hertz',...
# 12  {'MILLIAMPERE': {'code': 'MILLIAMPERE', 'label...
# 13  {'MICROMETER': {'code': 'MICROMETER', 'labels'...
# 14  {'WATT': {'code': 'WATT', 'labels': 'Watt', 'c...
# 15  {'CENTIBAR': {'code': 'CENTIBAR', 'labels': 'C...
# 16  {'MILLIOHM': {'code': 'MILLIOHM', 'labels': 'M...
# 17  {'METER_PER_SECOND': {'code': 'METER_PER_SECON...
# 18  {'CELSIUS': {'code': 'CELSIUS', 'labels': 'Cel...
# 19  {'MILLIVOLT': {'code': 'MILLIVOLT', 'labels': ...
# 20  {'MICROLITER': {'code': 'MICROLITER', 'labels'...
# 21  {'CUBIC_METER_PER_SECOND': {'code': 'CUBIC_MET...
# 22  {'MICROGRAM': {'code': 'MICROGRAM', 'labels': ...
# --- products -------------------------------
#       identifier  enabled       family  \
# 0     1111111171     True  accessories
# 1       13620748     True      led_tvs
# 2       15554974     True      webcams
# 3       12249740     True     scanners
# 4     1111111130     True     clothing
# ...          ...      ...          ...
# 1234  1111111125     True     clothing
# 1235  1111111126     True     clothing
# 1236  1111111127     True     clothing
# 1237  1111111128     True     clothing
# 1238  1111111129     True     clothing
#
#                                              categories groups  \
# 0     [master_accessories_bags, print_accessories, s...     []
# 1              [led_tvs, samsung, tvs_projectors_sales]     []
# 2                    [cameras_sales, logitech, webcams]     []
# 3                 [avision, print_scan_sales, scanners]     []
# 4             [master_men_blazers_deals, supplier_zaro]     []
# ...                                                 ...    ...
# 1234          [master_men_blazers_deals, supplier_zaro]     []
# 1235          [master_men_blazers_deals, supplier_zaro]     []
# 1236          [master_men_blazers_deals, supplier_zaro]     []
# 1237          [master_men_blazers_deals, supplier_zaro]     []
# 1238          [master_men_blazers_deals, supplier_zaro]     []
#
#                        created                   updated          parent  \
# 0    2022-02-18 12:17:31+00:00 2022-02-18 12:17:32+00:00            None
# 1    2022-02-18 12:17:31+00:00 2022-02-18 12:17:32+00:00            None
# 2    2022-02-18 12:17:31+00:00 2022-02-18 12:17:33+00:00            None
# 3    2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00            None
# 4    2022-02-18 12:18:13+00:00 2022-02-18 12:18:14+00:00  apollon_yellow
# ...                        ...                       ...             ...
# 1234 2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00    apollon_pink
# 1235 2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00     apollon_red
# 1236 2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00     apollon_red
# 1237 2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00  apollon_yellow
# 1238 2022-02-18 12:18:08+00:00 2022-02-18 12:18:09+00:00  apollon_yellow
#
#                                                  values
# 0     {'image': True, 'ean': True, 'name': True, 'we...
# 1     {'name': True, 'display_diagonal': True, 'desc...
# 2     {'maximum_video_resolution': True, 'name': Tru...
# 3     {'picture': True, 'name': True, 'description':...
# 4     {'size': True, 'color': True, 'supplier': True...
# ...                                                 ...
# 1234  {'size': True, 'color': True, 'supplier': True...
# 1235  {'size': True, 'color': True, 'supplier': True...
# 1236  {'size': True, 'color': True, 'supplier': True...
# 1237  {'size': True, 'color': True, 'supplier': True...
# 1238  {'size': True, 'color': True, 'supplier': True...
#
# [1239 rows x 9 columns]
