# %%
import pandas as pd

from src import config

# %%
products_df = pd.read_csv(config.dir_data / "dataset" / "products.csv")
products_df
# Out:
#                 family        brand categories  \
# 0   mobile_phone_cases    Mobiparts        s20
# 1   mobile_phone_cases    Mobiparts        s20
# 2   mobile_phone_cases    Mobiparts        s20
# 3   mobile_phone_cases    Mobiparts        s20
# 4   mobile_phone_cases    Mobiparts        s20
# ..                 ...          ...        ...
# 75  mobile_phone_cases  PanzerGlass  s20_ultra
# 76  mobile_phone_cases  PanzerGlass        s22
# 77  mobile_phone_cases  PanzerGlass  s22_ultra
# 78  mobile_phone_cases  PanzerGlass        s22
# 79  mobile_phone_cases  PanzerGlass   s22_plus
#
#                                                   url
# 0   https://icecat.biz/en/p/mobiparts/104889/mobil...
# 1   https://icecat.biz/en/p/mobiparts/mp-104927/mo...
# 2   https://icecat.biz/en/p/mobiparts/mp-104925/mo...
# 3   https://icecat.biz/en/p/mobiparts/mp-108422/mo...
# 4   https://icecat.biz/en/p/mobiparts/mp-104926/mo...
# ..                                                ...
# ...

# %% [markdown]
# Duplicates

# %%
products_df[products_df["url"].duplicated(False)]
# Out:
# Empty DataFrame
# Columns: [family, brand, categories, url]
# Index: []

# %% [markdown]
# Count instances of brand and categories

# %%
products_df[["brand", "url"]].groupby(["brand"]).count()
# Out:
#               url
# brand
# Cellularline   11
# Mobiparts      28
# PanzerGlass     8
# Samsung        33

# %%
products_df[["categories", "url"]].groupby(["categories"]).count()
# Out:
#             url
# categories
# s20          18
# s20_fe        2
# s20_plus     14
# s20_ultra    10
# s21          11
# s21_fe        5
# s21_plus     10
# s21_ultra     6
# s22           2
# s22_plus      1
# s22_ultra     1
