# %%
import pandas as pd

from src import akeneo, config

data_dir = config.dir_data / "dataset"

# %%
products_file_df = pd.read_csv(data_dir / "products.csv")
products_file_df
# Out:
#                  family      brand categories  \
# 0    mobile_phone_cases  Mobiparts        s20
# 1    mobile_phone_cases  Mobiparts        s20
# 2    mobile_phone_cases  Mobiparts        s20
# 3    mobile_phone_cases  Mobiparts        s20
# 4    mobile_phone_cases  Mobiparts        s20
# ..                  ...        ...        ...
# 117         smartphones    Samsung     s21_fe
# 118         smartphones    Samsung        s22
# 119         smartphones    Samsung        s22
# 120         smartphones    Samsung   s22_plus
# 121         smartphones    Samsung  s22_ultra
#
#                                                    url
# 0    https://icecat.biz/en/p/mobiparts/104889/mobil...
# 1    https://icecat.biz/en/p/mobiparts/mp-104927/mo...
# 2    https://icecat.biz/en/p/mobiparts/mp-104925/mo...
# 3    https://icecat.biz/en/p/mobiparts/mp-108422/mo...
# 4    https://icecat.biz/en/p/mobiparts/mp-104926/mo...
# ..                                                 ...
# 117  https://icecat.biz/de/p/samsung/sm-g990bzageud...
# 118  https://icecat.biz/de/p/samsung/sm-s901bzadeue...
# 119  https://icecat.biz/de/p/samsung/sm-s901bzkdeue...
# 120  https://icecat.biz/de/p/samsung/sm-s906bzgdeue...
# 121  https://icecat.biz/de/p/samsung/sm-s908bzwgeuh...
#
# [122 rows x 4 columns]

# %%
products_file_df.groupby("categories").count()
# Out:
#                          family  brand  url
# categories
# s20                          21     21   21
# s20,dup_s20                   2      2    2
# s20_fe                        5      5    5
# s20_plus                     19     19   19
# s20_ultra                    13     13   13
# s20_ultra,dup_s20_ultra       2      2    2
# s21                          14     14   14
# s21,dup_s21_128               2      2    2
# s21,dup_s21_256               2      2    2
# s21_fe                        9      9    9
# s21_plus                     12     12   12
# s21_plus,dup_s21_plus         2      2    2
# s21_ultra                     9      9    9
# s21_ultra,dup_s21_ultra       2      2    2
# s22                           4      4    4
# s22_plus                      2      2    2
# s22_ultra                     2      2    2
