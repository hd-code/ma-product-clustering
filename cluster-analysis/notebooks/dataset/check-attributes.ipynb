# %%
import pandas as pd

from src import akeneo

# %%
cache = akeneo.create_cache_from_env()

# %%
cache.fetch_data_from_api()

# %%
attr_df = pd.DataFrame(cache.attributes)
attr_df[attr_df["group"] == "faulty"]
# Out:
#              code                                             labels  \
# 6     icecat_1024  {'de_DE': 'Lautsprecher', 'en_GB': 'Speakers',...
# 28   icecat_13248  {'de_DE': 'Soziale Netzwerkdienste unterstützt...
# 36   icecat_14695  {'de_DE': 'unterstützte 4G-Bandbreiten', 'en_G...
# 39    icecat_1503  {'de_DE': 'Modulation', 'en_GB': 'Modulation',...
# 47    icecat_1574  {'de_DE': 'Sensor-Typ', 'en_GB': 'Sensor type'...
# 60   icecat_16923  {'de_DE': '3G-Standards', 'en_GB': '3G standar...
# 63    icecat_1742  {'de_DE': 'USB-Stecker', 'en_GB': 'USB connect...
# 66    icecat_1766  {'de_DE': 'Produktfarbe', 'en_GB': 'Product co...
# 78    icecat_1809  {'de_DE': 'Sprachcodec', 'en_GB': 'Voice codec...
# 84    icecat_1830  {'de_DE': 'Mitgelieferte Kabel', 'en_GB': 'Cab...
# 97    icecat_2102  {'de_DE': 'ISO-Empfindlichkeit', 'en_GB': 'ISO...
# 105   icecat_2196  {'de_DE': 'Prozessorfamilie', 'en_GB': 'Proces...
# 109   icecat_2224  {'de_DE': 'Unterstützte Audioformate', 'en_GB'...
# 137  icecat_27575  {'de_DE': 'Verschluss', 'en_GB': 'Closure', 'e...
# 151   icecat_2963  {'de_DE': 'Auflösung bei Capture Geschwindigke...
# 235  icecat_40712  {'de_DE': 'Technologie mit hohem Dynamikbereic...
# 243   icecat_4133  {'de_DE': 'Bluetooth-Profile', 'en_GB': 'Bluet...
# 277  icecat_42369  {'de_DE': '5G-Bänder unterstützt', 'en_GB': '5...
# 290  icecat_42513  {'de_DE': 'Nachhaltigkeitszertifikate', 'en_GB...
# 292  icecat_42514  {'de_DE': 'Nachhaltigkeitsorganisationen', 'en...
# 295  icecat_42516  {'de_DE': 'Enthält nicht', 'en_GB': 'Doesn't c...
# 297  icecat_42521  {'de_DE': 'Recyceltes Material', 'en_GB': 'Rec...
# 302    icecat_432  {'de_DE': 'WLAN-Standards', 'en_GB': 'Wi-Fi st...
# 310    icecat_442  {'de_DE': 'Audio-System', 'en_GB': 'Audio syst...
# 317   icecat_4463  {'de_DE': 'Verpackungsart', 'en_GB': 'Package ...
# 319    icecat_454  {'de_DE': 'Unterstützte Sicherheitsalgorithmen...
# 324   icecat_4851  {'de_DE': 'Unterstützte Video-Modi', 'en_GB': ...
# 333   icecat_5214  {'de_DE': 'Gehäusematerial', 'en_GB': 'Housing...
# 337    icecat_614  {'de_DE': 'Grafikkarte', 'en_GB': 'Graphics ca...
# 342   icecat_6697  {'de_DE': 'Flash-Typ', 'en_GB': 'Flash type', ...
# 346   icecat_6893  {'de_DE': 'Unterstützte Videoformate', 'en_GB'...
# 354    icecat_730  {'de_DE': 'Kompatible Speicherkarten', 'en_GB'...
# 358     icecat_75  {'de_DE': 'Plattform', 'en_GB': 'Platform', 'e...
# 367    icecat_771  {'de_DE': 'Formfaktor', 'en_GB': 'Form factor'...
# 372   icecat_7986  {'de_DE': 'Unterstützt Windows-Betriebssysteme...
# 374   icecat_7987  {'de_DE': 'Unterstützt Mac-Betriebssysteme', '...
# 379   icecat_8072  {'de_DE': 'Schutzfunktion', 'en_GB': 'Protecti...
# 384   icecat_8367  {'de_DE': 'unterstützte 3G-Bandbreiten', 'en_G...
# 397   icecat_8745  {'de_DE': 'Videoaufnahme-Modi', 'en_GB': 'Vide...
# 403    icecat_898  {'de_DE': 'Material', 'en_GB': 'Material', 'en...
# 423   icecat_9780  {'de_DE': 'Unterstützte Google-Anwendungen', '...
#
#                             type  localizable  scopable  unique   group  \
# 6             AttributeType.TEXT         True      True   False  faulty
# 28   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 36   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 39   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 47            AttributeType.TEXT         True      True   False  faulty
# 60   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 63   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 66   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 78   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 84   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 97   AttributeType.SELECT_SINGLE         True      True   False  faulty
# 105           AttributeType.TEXT         True      True   False  faulty
# 109  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 137           AttributeType.TEXT         True      True   False  faulty
# 151  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 235  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 243  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 277  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 290  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 292  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 295  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 297  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 302  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 310           AttributeType.TEXT         True      True   False  faulty
# 317           AttributeType.TEXT         True      True   False  faulty
# 319  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 324  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 333  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 337           AttributeType.TEXT         True      True   False  faulty
# 342           AttributeType.TEXT         True      True   False  faulty
# 346  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 354  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 358           AttributeType.TEXT         True      True   False  faulty
# 367           AttributeType.TEXT         True      True   False  faulty
# 372  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 374  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 379  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 384  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 397  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 403  AttributeType.SELECT_SINGLE         True      True   False  faulty
# 423  AttributeType.SELECT_SINGLE         True      True   False  faulty
#
#                                           group_labels  sort_order  \
# 6    {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1024
# 28   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       13248
# 36   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       14695
# 39   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1503
# 47   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1574
# 60   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       16923
# 63   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1742
# 66   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1766
# 78   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1809
# 84   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        1830
# 97   {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        2102
# 105  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        2196
# 109  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        2224
# 137  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       27575
# 151  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        2963
# 235  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       40712
# 243  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        4133
# 277  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       42369
# 290  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       42513
# 292  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       42514
# 295  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       42516
# 297  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...       42521
# 302  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         432
# 310  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         442
# 317  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        4463
# 319  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         454
# 324  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        4851
# 333  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        5214
# 337  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         614
# 342  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        6697
# 346  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        6893
# 354  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         730
# 358  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...          75
# 367  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         771
# 372  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        7986
# 374  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        7987
# 379  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        8072
# 384  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        8367
# 397  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        8745
# 403  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...         898
# 423  {'en_US': 'Faulty', 'en_GB': 'Faulty', 'de_DE'...        9780
#
#     allowed_extensions  ... max_file_size metric_family minimum_input_length  \
# 6                   []  ...          None          None                 None
# 28                  []  ...          None          None                 None
# 36                  []  ...          None          None                 None
# 39                  []  ...          None          None                 None
# 47                  []  ...          None          None                 None
# 60                  []  ...          None          None                 None
# 63                  []  ...          None          None                 None
# 66                  []  ...          None          None                 None
# 78                  []  ...          None          None                 None
# 84                  []  ...          None          None                 None
# 97                  []  ...          None          None                 None
# 105                 []  ...          None          None                 None
# 109                 []  ...          None          None                 None
# 137                 []  ...          None          None                 None
# 151                 []  ...          None          None                 None
# 235                 []  ...          None          None                 None
# 243                 []  ...          None          None                 None
# 277                 []  ...          None          None                 None
# 290                 []  ...          None          None                 None
# 292                 []  ...          None          None                 None
# 295                 []  ...          None          None                 None
# 297                 []  ...          None          None                 None
# 302                 []  ...          None          None                 None
# 310                 []  ...          None          None                 None
# 317                 []  ...          None          None                 None
# 319                 []  ...          None          None                 None
# 324                 []  ...          None          None                 None
# 333                 []  ...          None          None                 None
# 337                 []  ...          None          None                 None
# 342                 []  ...          None          None                 None
# 346                 []  ...          None          None                 None
# 354                 []  ...          None          None                 None
# 358                 []  ...          None          None                 None
# 367                 []  ...          None          None                 None
# 372                 []  ...          None          None                 None
# 374                 []  ...          None          None                 None
# 379                 []  ...          None          None                 None
# 384                 []  ...          None          None                 None
# 397                 []  ...          None          None                 None
# 403                 []  ...          None          None                 None
# 423                 []  ...          None          None                 None
#
#     negative_allowed number_min number_max reference_data_name  \
# 6               None       None       None                None
# 28              None       None       None                None
# 36              None       None       None                None
# 39              None       None       None                None
# 47              None       None       None                None
# 60              None       None       None                None
# 63              None       None       None                None
# 66              None       None       None                None
# 78              None       None       None                None
# 84              None       None       None                None
# 97              None       None       None                None
# 105             None       None       None                None
# 109             None       None       None                None
# 137             None       None       None                None
# 151             None       None       None                None
# 235             None       None       None                None
# 243             None       None       None                None
# 277             None       None       None                None
# 290             None       None       None                None
# 292             None       None       None                None
# 295             None       None       None                None
# 297             None       None       None                None
# 302             None       None       None                None
# 310             None       None       None                None
# 317             None       None       None                None
# 319             None       None       None                None
# 324             None       None       None                None
# 333             None       None       None                None
# 337             None       None       None                None
# 342             None       None       None                None
# 346             None       None       None                None
# 354             None       None       None                None
# 358             None       None       None                None
# 367             None       None       None                None
# 372             None       None       None                None
# 374             None       None       None                None
# 379             None       None       None                None
# 384             None       None       None                None
# 397             None       None       None                None
# 403             None       None       None                None
# 423             None       None       None                None
#
#     validation_rule validation_regexp wysiwyg_enabled
# 6              None              None            None
# 28             None              None            None
# 36             None              None            None
# 39             None              None            None
# 47             None              None            None
# 60             None              None            None
# 63             None              None            None
# 66             None              None            None
# 78             None              None            None
# 84             None              None            None
# 97             None              None            None
# 105            None              None            None
# 109            None              None            None
# 137            None              None            None
# 151            None              None            None
# 235            None              None            None
# 243            None              None            None
# 277            None              None            None
# 290            None              None            None
# 292            None              None            None
# 295            None              None            None
# 297            None              None            None
# 302            None              None            None
# 310            None              None            None
# 317            None              None            None
# 319            None              None            None
# 324            None              None            None
# 333            None              None            None
# 337            None              None            None
# 342            None              None            None
# 346            None              None            None
# 354            None              None            None
# 358            None              None            None
# 367            None              None            None
# 372            None              None            None
# 374            None              None            None
# 379            None              None            None
# 384            None              None            None
# 397            None              None            None
# 403            None              None            None
# 423            None              None            None
#
# [41 rows x 28 columns]
