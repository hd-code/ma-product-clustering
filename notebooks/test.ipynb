# %%
import pandas as pd

from akeneo import AkeneoProduct, create_from_env


connector, client = create_from_env()

# %%
prods = connector.get_products()
pd.DataFrame(AkeneoProduct.get_products_values(prods))
# Out:
#                                                   image            ean  \
# 0     f/e/9/6/fe960148cdaa746093eb734cd82a36ffe9b6ff...  1234567890183
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4     8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890142
# ...                                                 ...            ...
# 1234  8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890137
# 1235  8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890138
# 1236  8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890139
# 1237  8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890140
# 1238  8/4/f/9/84f9f9f4a41331b349c54d2a67373fa1b7df1d...  1234567890141
#
#                                                    name    weight  \
# 0                                                   Bag  500.0000
# 1                         Samsung UE40ES5500PXZT LED TV       NaN
# 2                                         Logitech C170       NaN
# 3                                          Avision AV36       NaN
# 4     Long gray suit jacket and matching pants unstr...  600.0000
# ...                                                 ...       ...
# 1234  Long gray suit jacket and matching pants unstr...  600.0000
# 1235  Long gray suit jacket and matching pants unstr...  900.0000
# 1236  Long gray suit jacket and matching pants unstr...  800.0000
# 1237  Long gray suit jacket and matching pants unstr...  800.0000
# 1238  Long gray suit jacket and matching pants unstr...  800.0000
#
#       display_diagonal                                        description  \
# 0                  NaN                                                NaN
# 1                 40.0  Samsung UE40ES5500PXZT. HD type: Full HD, Disp...
# 2                  NaN  <b>The easy way to start video calling and sen...
# 3                  NaN  <b>Mobile power by USB</b>\nDon’t just haul th...
# 4                  NaN  Long gray suit jacket and matching pants unstr...
# ...                ...                                                ...
# 1234               NaN  Long gray suit jacket and matching pants unstr...
# 1235               NaN  Long gray suit jacket and matching pants unstr...
# 1236               NaN  Long gray suit jacket and matching pants unstr...
# 1237               NaN  Long gray suit jacket and matching pants unstr...
# 1238               NaN  Long gray suit jacket and matching pants unstr...
#
#                   release_date maximum_video_resolution total_megapixels  \
# 0                          NaT                      NaN              NaN
# 1    2012-03-29 00:00:00+00:00                      NaN              NaN
# 2    2012-09-13 00:00:00+00:00                640_x_480                5
# 3    2012-01-05 00:00:00+00:00                      NaN              NaN
# 4                          NaT                      NaN              NaN
# ...                        ...                      ...              ...
# 1234                       NaT                      NaN              NaN
# 1235                       NaT                      NaN              NaN
# 1236                       NaT                      NaN              NaN
# 1237                       NaT                      NaN              NaN
# 1238                       NaT                      NaN              NaN
#
#                                                 picture  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3     c/2/d/f/c2df1e701322f576b6e477653e8db7ebe78ea2...  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 1234                                                NaN  ...
# 1235                                                NaN  ...
# 1236                                                NaN  ...
# 1237                                                NaN  ...
# 1238                                                NaN  ...
#
#      power_requirements eu_shoes_size maximum_frame_rate image_stabilizer  \
# 0                   NaN           NaN                NaN              NaN
# 1                   NaN           NaN                NaN              NaN
# 2                   NaN           NaN                NaN              NaN
# 3                   NaN           NaN                NaN              NaN
# 4                   NaN           NaN                NaN              NaN
# ...                 ...           ...                ...              ...
# 1234                NaN           NaN                NaN              NaN
# 1235                NaN           NaN                NaN              NaN
# 1236                NaN           NaN                NaN              NaN
# 1237                NaN           NaN                NaN              NaN
# 1238                NaN           NaN                NaN              NaN
#
#      brand material meta_title composition care_instructions main_color
# 0      NaN      NaN        NaN         NaN               NaN        NaN
# 1      NaN      NaN        NaN         NaN               NaN        NaN
# 2      NaN      NaN        NaN         NaN               NaN        NaN
# 3      NaN      NaN        NaN         NaN               NaN        NaN
# 4      NaN      NaN        NaN         NaN               NaN        NaN
# ...    ...      ...        ...         ...               ...        ...
# 1234   NaN      NaN        NaN         NaN               NaN        NaN
# 1235   NaN      NaN        NaN         NaN               NaN        NaN
# 1236   NaN      NaN        NaN         NaN               NaN        NaN
# 1237   NaN      NaN        NaN         NaN               NaN        NaN
# 1238   NaN      NaN        NaN         NaN               NaN        NaN
#
# [1239 rows x 41 columns]

# %%
df = pd.DataFrame(client.get_routes())
df[df["is_list"]].sort_values("path")

# %%
prods = client.get_list("pim_api_product_list")
prods_values = [prod["values"] for prod in prods]
df = pd.DataFrame(prods_values)
df

# %%
params = {"locales": "en_US", "scope": "ecommerce", "attributes": "description"}
prods = client.get_list("pim_api_product_list", params=params)
prods_values = [prod["values"] for prod in prods]
df = pd.DataFrame(prods_values)
df

# %%
params = {"locales": "en_US", "attributes": "description,ean"}
prods = client.get_list("pim_api_product_list", params=params)
prods_values = [prod["values"] for prod in prods]
df = pd.DataFrame(prods_values)
df

# %%
params = {"locales": "en_US", "attributes": "description,ean,brand,collection,display_diagonal,display_color"}
prods = client.get_list("pim_api_product_list", params=params)
prods_values = [prod["values"] for prod in prods]
df = pd.DataFrame(prods_values)
df
